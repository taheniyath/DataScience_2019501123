# %%
import pandas as pd
import numpy as np

# %%
ratings = pd.read_csv("E:/DataScience_2019501123/DADV/assignments/data/title.ratings.tsv", delimiter = '\t')

# %%
basics_movie = pd.read_csv("E:/DataScience_2019501123/DADV/assignments/data/title.basic.tsv", delimiter = '\t')
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
basics_movie['startYear'] = pd.to_numeric(basics_movie['startYear'], errors='coerce')

# %%
year = basics_movie[(basics_movie.startYear >= 1900) & (basics_movie.startYear <= 1999)]
year
# Out:
#             tconst  titleType                             primaryTitle  \
# 157      tt0000160      short                 The Last Days of Pompeii
# 217      tt0000220      short           The Artist and the Flower Girl
# 262      tt0000265      short                          Above the Limit
# 263      tt0000266      short                       Above the Speedway
# 264      tt0000267      short                                L'angélus
# ...            ...        ...                                      ...
# 7903159  tt9916660  tvEpisode            Episode dated 2 February 1993
# 7903196  tt9916738  tvEpisode     Meditation for a Young Boy Confirmed
# 7903197  tt9916740  tvEpisode  From All Saints' Church, Burton Dassett
# 7903198  tt9916742  tvEpisode            From Victoria College, Jersey
# 7903239  tt9916830  tvEpisode                             Episode #2.6
#
#                                    originalTitle isAdult  startYear endYear  \
# ...

# %%
year_rating_merged = pd.merge(year, ratings, on='tconst')
year_rating_merged
# Out:
#            tconst  titleType  \
# 0       tt0000160      short
# 1       tt0000265      short
# 2       tt0000269      short
# 3       tt0000271      short
# 4       tt0000272      short
# ...           ...        ...
# 370620  tt9909866      video
# 370621  tt9914702  tvEpisode
# 370622  tt9915498      video
# 370623  tt9915946      movie
# 370624  tt9916220  tvEpisode
#
#                                              primaryTitle  \
# 0                                The Last Days of Pompeii
# 1                                         Above the Limit
# 2       Army Life; or, How Soldiers Are Made: Mounted ...
# 3                          Arrivée de Pierette et Pierrot
# 4                             As Seen Through a Telescope
# ...                                                   ...
# 370620                                               Nora
# 370621                      Episode dated 5 February 1988
# 370622   R. Kelly: If I Could Turn Back the Hands of Time
# ...

# %%
only_movies = year_rating_merged.loc[year_rating_merged['titleType'] == 'movie']
only_movies
# Out:
#            tconst titleType                   primaryTitle  \
# 114     tt0000502     movie                       Bohemios
# 148     tt0000574     movie    The Story of the Kelly Gang
# 157     tt0000591     movie               The Prodigal Son
# 172     tt0000615     movie             Robbery Under Arms
# 180     tt0000630     movie                         Hamlet
# ...           ...       ...                            ...
# 370541  tt9870502     movie  Star Trek: The Infinite Chain
# 370587  tt9890850     movie                Leyli va Macnun
# 370598  tt9894108     movie                      vajau ka?
# 370610  tt9909462     movie      An Unprecedented Campaign
# 370623  tt9915946     movie               Nuestra película
#
#                         originalTitle isAdult  startYear endYear  \
# 114                          Bohemios       0     1905.0      \N
# 148       The Story of the Kelly Gang       0     1906.0      \N
# ...

# %%
popular_movie = only_movies.sort_values('numVotes', ascending = False)

# %%
movies = only_movies[['originalTitle','startYear','averageRating', 'numVotes' ]]
movies
# Out:
#                         originalTitle  startYear  averageRating  numVotes
# 114                          Bohemios     1905.0            4.5         8
# 148       The Story of the Kelly Gang     1906.0            6.1       632
# 157                 L'enfant prodigue     1907.0            6.0         5
# 172                Robbery Under Arms     1907.0            4.5        14
# 180                            Amleto     1908.0            3.8        12
# ...                               ...        ...            ...       ...
# 370541  Star Trek: The Infinite Chain     1994.0            5.8         5
# 370587                Leyli va Macnun     1961.0            5.9         8
# 370598                      vajau ka?     1996.0            7.5        15
# 370610               Nebyvalyy pokhod     1931.0            7.5         8
# 370623               Nuestra película     1993.0            6.2         6
#
# [123008 rows x 4 columns]

# %%
movies.to_csv('E:/DataScience_2019501123/DADV/assignments/movies_1900.csv' )
