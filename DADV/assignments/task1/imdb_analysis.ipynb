# %%
import pandas as pd
import numpy as np

# %%
ratings = pd.read_csv("E:/DataScience_2019501123/DADV/assignments/data/title.ratings.tsv", delimiter = '\t')

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1702
# 1  tt0000002            6.1       210
# 2  tt0000003            6.5      1458
# 3  tt0000004            6.2       123
# 4  tt0000005            6.2      2260

# %%
basics_movie = pd.read_csv("E:/DataScience_2019501123/DADV/assignments/data/title.basic.tsv", delimiter = '\t')
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
basics_movie.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           object
# startYear         object
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
basics_movie['startYear'] = pd.to_numeric(basics_movie['startYear'], errors='coerce')

# %%
basics_movie.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult            object
# startYear         float64
# endYear            object
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
year = basics_movie[(basics_movie.startYear >= 2000) & (basics_movie.startYear <= 2009)]
year
# Out:
#             tconst  titleType            primaryTitle           originalTitle  \
# 15181    tt0015414      movie  La tierra de los toros  La tierra de los toros
# 18034    tt0018295      short       El puño de hierro       El puño de hierro
# 33808    tt0034413      short      Youth Gets a Break      Youth Gets a Break
# 34808    tt0035423      movie          Kate & Leopold          Kate & Leopold
# 35548    tt0036177      movie      Muhomatsu no issho      Muhomatsu no issho
# ...            ...        ...                     ...                     ...
# 7903222  tt9916794  tvEpisode           Episode #2.33           Episode #2.33
# 7903223  tt9916796  tvEpisode           Episode #2.34           Episode #2.34
# 7903224  tt9916798  tvEpisode           Episode #2.36           Episode #2.36
# 7903225  tt9916800  tvEpisode           Episode #2.35           Episode #2.35
# 7903227  tt9916804  tvEpisode           Episode #2.37           Episode #2.37
#
#         isAdult  startYear endYear runtimeMinutes                  genres
# 15181         0     2000.0      \N             60                      \N
# 18034         0     2004.0      \N             40      Action,Drama,Short
# 33808         0     2001.0      \N             20                   Short
# 34808         0     2001.0      \N            118  Comedy,Fantasy,Romance
# 35548         0     2008.0      \N            100        Action,Adventure
# ...         ...        ...     ...            ...                     ...
# 7903222       0     2009.0      \N             \N     Action,Drama,Family
# 7903223       0     2009.0      \N             \N     Action,Drama,Family
# 7903224       0     2009.0      \N             \N     Action,Drama,Family
# 7903225       0     2009.0      \N             \N     Action,Drama,Family
# 7903227       0     2009.0      \N             \N     Action,Drama,Family
#
# [1429039 rows x 9 columns]

# %%
year_rating_merged = pd.merge(year, ratings, on='tconst')
year_rating_merged.head()
# Out:
#       tconst titleType                primaryTitle  \
# 0  tt0015414     movie      La tierra de los toros
# 1  tt0018295     short           El puño de hierro
# 2  tt0035423     movie              Kate & Leopold
# 3  tt0036177     movie          Muhomatsu no issho
# 4  tt0064730     movie  Japan Organized Crime Boss
#
#                 originalTitle isAdult  startYear endYear runtimeMinutes  \
# 0      La tierra de los toros       0     2000.0      \N             60
# 1           El puño de hierro       0     2004.0      \N             40
# 2              Kate & Leopold       0     2001.0      \N            118
# 3          Muhomatsu no issho       0     2008.0      \N            100
# 4  Nihon boryoku-dan: Kumicho       0     2000.0      \N             97
#
#                    genres  averageRating  numVotes
# 0                      \N            5.4        11
# 1      Action,Drama,Short            6.6        31
# 2  Comedy,Fantasy,Romance            6.4     79778
# 3        Action,Adventure            7.2        82
# 4            Action,Crime            6.9       188

# %%
only_movies = year_rating_merged.loc[year_rating_merged['titleType'] == 'movie']
only_movies
# Out:
#            tconst titleType                   primaryTitle  \
# 0       tt0015414     movie         La tierra de los toros
# 2       tt0035423     movie                 Kate & Leopold
# 3       tt0036177     movie             Muhomatsu no issho
# 4       tt0064730     movie     Japan Organized Crime Boss
# 6       tt0079644     movie                  November 1828
# ...           ...       ...                            ...
# 256156  tt9815124     movie                     Mami Jarum
# 256203  tt9874290     movie  Star Trek: Incident at Beta 9
# 256204  tt9876412     movie  Star Trek: The Final Darkness
# 256219  tt9881364     movie                           Gaja
# 256242  tt9900614     movie                      Lady Boss
#
#                         originalTitle isAdult  startYear endYear  \
# 0              La tierra de los toros       0     2000.0      \N
# 2                      Kate & Leopold       0     2001.0      \N
# 3                  Muhomatsu no issho       0     2008.0      \N
# 4          Nihon boryoku-dan: Kumicho       0     2000.0      \N
# 6                       November 1828       0     2001.0      \N
# ...                               ...     ...        ...     ...
# 256156                     Mami Jarum       0     2002.0      \N
# 256203  Star Trek: Incident at Beta 9       0     2002.0      \N
# 256204  Star Trek: The Final Darkness       0     2004.0      \N
# 256219                           Gaja       0     2008.0      \N
# 256242                      Lady Boss       0     2005.0      \N
#
#        runtimeMinutes                  genres  averageRating  numVotes
# 0                  60                      \N            5.4        11
# 2                 118  Comedy,Fantasy,Romance            6.4     79778
# 3                 100        Action,Adventure            7.2        82
# 4                  97            Action,Crime            6.9       188
# 6                 140               Drama,War            7.2        30
# ...               ...                     ...            ...       ...
# 256156             95                  Comedy            5.1        22
# 256203             57                  Sci-Fi            4.6         7
# 256204             85                  Sci-Fi            4.4         5
# 256219             \N   Action,Comedy,Romance            7.6        40
# 256242             \N                  Comedy            5.2        18
#
# [45792 rows x 11 columns]

# %%
popular_movie = only_movies.sort_values('numVotes', ascending = False)

# %%
print(popular_movie.head(10)['averageRating'].mean())
# Out:
# 8.580000000000002

# %%
votes = ratings[ratings['numVotes'] > 1000]
votes
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1702
# 2        tt0000003            6.5      1458
# 4        tt0000005            6.2      2260
# 7        tt0000008            5.5      1874
# 9        tt0000010            6.9      6323
# ...            ...            ...       ...
# 1151409  tt9913050            8.3      1201
# 1151510  tt9913754            7.2      1011
# 1151527  tt9914552            9.0      1010
# 1151583  tt9916270            5.7      1047
# 1151586  tt9916362            6.3      3218
#
# [61667 rows x 3 columns]

# %%
votes_merged = pd.merge(votes, basics_movie, on = 'tconst')

# %%
year = votes_merged[(votes_merged['startYear'] >= 1900) & (votes_merged['startYear'] < 2000)]

# %%
year_output = year.groupby('startYear').agg(avgR = ('averageRating', np.mean)).reset_index()

# %%
flag = 0
final_yr = 0
for i in range(1, len(year_output)):
    a = year_output.loc[i, 'avgR']
    b = year_output.loc[i-1, 'avgR']
    temp = abs(a - b)
    if temp > flag:
        flag = temp
        final_yr = year_output.loc[[i], ['startYear']]
final_yr
# Out:
#    startYear
# 3     1903.0

# %%
rating_merged = pd.merge(ratings, basics_movie, on = 'tconst')
rating_merged
# Out:
#             tconst  averageRating  numVotes  titleType  \
# 0        tt0000001            5.7      1702      short
# 1        tt0000002            6.1       210      short
# 2        tt0000003            6.5      1458      short
# 3        tt0000004            6.2       123      short
# 4        tt0000005            6.2      2260      short
# ...            ...            ...       ...        ...
# 1151598  tt9916682            5.6         5  tvEpisode
# 1151599  tt9916690            6.6         5  tvEpisode
# 1151600  tt9916720            6.4        80      short
# 1151601  tt9916766            6.9        16  tvEpisode
# 1151602  tt9916778            7.5        27  tvEpisode
#
#                              primaryTitle                     originalTitle  \
# 0                              Carmencita                        Carmencita
# 1                  Le clown et ses chiens            Le clown et ses chiens
# 2                          Pauvre Pierrot                    Pauvre Pierrot
# 3                             Un bon bock                       Un bon bock
# 4                        Blacksmith Scene                  Blacksmith Scene
# ...                                   ...                               ...
# 1151598  Horrid Henry It's all Your Fault  Horrid Henry It's all Your Fault
# 1151599    Horrid Henry Delivers the Milk    Horrid Henry Delivers the Milk
# 1151600                         The Nun 2                         The Nun 2
# 1151601                    Episode #10.15                    Episode #10.15
# 1151602                            Escape                            Escape
#
#         isAdult  startYear endYear runtimeMinutes                    genres
# 0             0     1894.0      \N              1         Documentary,Short
# 1             0     1892.0      \N              5           Animation,Short
# 2             0     1892.0      \N              4  Animation,Comedy,Romance
# 3             0     1892.0      \N             12           Animation,Short
# 4             0     1893.0      \N              1              Comedy,Short
# ...         ...        ...     ...            ...                       ...
# 1151598       0     2012.0      \N             10   Animation,Comedy,Family
# 1151599       0     2012.0      \N             10   Animation,Comedy,Family
# 1151600       0     2019.0      \N             10     Comedy,Horror,Mystery
# 1151601       0     2019.0      \N             43         Family,Reality-TV
# 1151602       0     2019.0      \N             \N     Drama,Mystery,Romance
#
# [1151603 rows x 11 columns]

# %%
vote = rating_merged[rating_merged['numVotes']>= 1000]
vote
# Out:
#             tconst  averageRating  numVotes  titleType  \
# 0        tt0000001            5.7      1702      short
# 2        tt0000003            6.5      1458      short
# 4        tt0000005            6.2      2260      short
# 7        tt0000008            5.5      1874      short
# 9        tt0000010            6.9      6323      short
# ...            ...            ...       ...        ...
# 1151409  tt9913050            8.3      1201  tvEpisode
# 1151510  tt9913754            7.2      1011  tvEpisode
# 1151527  tt9914552            9.0      1010      short
# 1151583  tt9916270            5.7      1047      movie
# 1151586  tt9916362            6.3      3218      movie
#
#                                      primaryTitle  \
# 0                                      Carmencita
# 2                                  Pauvre Pierrot
# 4                                Blacksmith Scene
# 7          Edison Kinetoscopic Record of a Sneeze
# 9                             Leaving the Factory
# ...                                           ...
# 1151409  The Boar Bares Its Fangs, Zenitsu Sleeps
# 1151510                                Psalm 46:5
# 1151527                               The Curtain
# 1151583                  Il talento del calabrone
# 1151586                                     Coven
#
#                                     originalTitle isAdult  startYear endYear  \
# 0                                      Carmencita       0     1894.0      \N
# 2                                  Pauvre Pierrot       0     1892.0      \N
# 4                                Blacksmith Scene       0     1893.0      \N
# 7          Edison Kinetoscopic Record of a Sneeze       0     1894.0      \N
# 9             La sortie de l'usine Lumière à Lyon       0     1895.0      \N
# ...                                           ...     ...        ...     ...
# 1151409  The Boar Bares Its Fangs, Zenitsu Sleeps       0     2019.0      \N
# 1151510                                Psalm 46:5       0     2020.0      \N
# 1151527                               The Curtain       0     2019.0      \N
# 1151583                  Il talento del calabrone       0     2020.0      \N
# 1151586                                  Akelarre       0     2020.0      \N
#
#         runtimeMinutes                    genres
# 0                    1         Documentary,Short
# 2                    4  Animation,Comedy,Romance
# 4                    1              Comedy,Short
# 7                    1         Documentary,Short
# 9                    1         Documentary,Short
# ...                ...                       ...
# 1151409             24  Action,Animation,Fantasy
# 1151510             50      Action,Drama,Fantasy
# 1151527             \N             Mystery,Short
# 1151583             84                  Thriller
# 1151586             92   Adventure,Drama,History
#
# [61709 rows x 11 columns]

# %%
vote_output = vote.groupby('startYear').agg(avgR = ('averageRating', np.mean)).reset_index()

# %%
vote_output
# Out:
#      startYear      avgR
# 0       1874.0  6.900000
# 1       1878.0  7.400000
# 2       1887.0  5.200000
# 3       1888.0  6.500000
# 4       1890.0  5.000000
# ..         ...       ...
# 131     2017.0  7.191322
# 132     2018.0  7.142186
# 133     2019.0  7.206905
# 134     2020.0  7.140107
# 135     2021.0  7.351389
#
# [136 rows x 2 columns]

# %%
vote_output = vote_output[vote_output.startYear != 2013]
vote_output
# Out:
#      startYear      avgR
# 0       1874.0  6.900000
# 1       1878.0  7.400000
# 2       1887.0  5.200000
# 3       1888.0  6.500000
# 4       1890.0  5.000000
# ..         ...       ...
# 131     2017.0  7.191322
# 132     2018.0  7.142186
# 133     2019.0  7.206905
# 134     2020.0  7.140107
# 135     2021.0  7.351389
#
# [135 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train = vote_output['startYear'].values.reshape(-1,1)
y_train = vote_output['avgR'].values.reshape(-1,1)

# %%
model = LinearRegression().fit(x_train,y_train)

# %%
xtest = np.array([2013]).reshape(-1,1)
prediction = model.predict(xtest)
print(prediction)
# Out:
# [[7.0136479]]

# %%
# To visualize
import matplotlib.pyplot as plt

# %%
temp_pred = model.predict(x_train)
plt.scatter(x_train, y_train)
plt.plot(x_train, temp_pred, color='red')
plt.show()

# %%
corrl_year = basics_movie[(basics_movie['startYear']>= 1900) & (basics_movie['startYear'] < 2000)]

# %%
corrl_Data = pd.merge(ratings, corrl_year, on='tconst')
corrl_Data
# Out:
#            tconst  averageRating  numVotes  titleType  \
# 0       tt0000160            5.4        11      short
# 1       tt0000265            4.3       103      short
# 2       tt0000269            4.9       100      short
# 3       tt0000271            6.2         8      short
# 4       tt0000272            5.6       710      short
# ...           ...            ...       ...        ...
# 370620  tt9909866            4.3        10      video
# 370621  tt9914702            7.2        15  tvEpisode
# 370622  tt9915498            5.8         6      video
# 370623  tt9915946            6.2         6      movie
# 370624  tt9916220            7.1        13  tvEpisode
#
#                                              primaryTitle  \
# 0                                The Last Days of Pompeii
# 1                                         Above the Limit
# 2       Army Life; or, How Soldiers Are Made: Mounted ...
# 3                          Arrivée de Pierette et Pierrot
# 4                             As Seen Through a Telescope
# ...                                                   ...
# 370620                                               Nora
# 370621                      Episode dated 5 February 1988
# 370622   R. Kelly: If I Could Turn Back the Hands of Time
# 370623                                   Nuestra película
# 370624                          Episode dated 18 May 1988
#
#                                            originalTitle isAdult  startYear  \
# 0                               The Last Days of Pompeii       0     1900.0
# 1                                        Above the Limit       0     1900.0
# 2                                              Army Life       0     1900.0
# 3                         Arrivée de Pierette et Pierrot       0     1900.0
# 4                            As Seen Through a Telescope       0     1900.0
# ...                                                  ...     ...        ...
# 370620                                              Nora       0     1985.0
# 370621                     Episode dated 5 February 1988       0     1988.0
# 370622  R. Kelly: If I Could Turn Back the Hands of Time       0     1999.0
# 370623                                  Nuestra película       0     1993.0
# 370624                         Episode dated 18 May 1988       0     1988.0
#
#        endYear runtimeMinutes                      genres
# 0           \N             \N                 Drama,Short
# 1           \N             \N                Comedy,Short
# 2           \N             \N           Documentary,Short
# 3           \N             \N                       Short
# 4           \N              1                Comedy,Short
# ...        ...            ...                         ...
# 370620      \N             45  Action,Adventure,Animation
# 370621      \N             \N                          \N
# 370622      \N             \N                 Music,Short
# 370623      \N             96                 Documentary
# 370624      \N             \N                          \N
#
# [370625 rows x 11 columns]

# %%
years = list(corrl_Data['startYear'].unique())
correlation_year = pd.DataFrame()
for year in years:
    X=corrl_Data[corrl_Data['startYear']==year].iloc[:,[1,2]]
    corr = X.corr()
    corr = corr['averageRating'][1]
    newRow = {'Correlation':corr,'Year':year}
    correlation_year = correlation_year.append(newRow, ignore_index=True)
correlation_year = correlation_year.reindex(columns=['Year', 'Correlation'])
correlation_year
# Out:
#       Year  Correlation
# 0   1900.0     0.232215
# 1   1901.0     0.262765
# 2   1902.0     0.206988
# 3   1903.0     0.167379
# 4   1904.0     0.277191
# ..     ...          ...
# 95  1997.0     0.021080
# 96  1999.0     0.028864
# 97  1998.0     0.021968
# 98  1994.0     0.033998
# 99  1996.0     0.007379
#
# [100 rows x 2 columns]

# %%
import matplotlib.pyplot
import pylab
matplotlib.pyplot.scatter(correlation_year['Year'],correlation_year['Correlation'])

# %%
plt.bar(np.arange(len(correlation_year['Year'])), correlation_year['Correlation'])
# Out:
# <BarContainer object of 100 artists>
