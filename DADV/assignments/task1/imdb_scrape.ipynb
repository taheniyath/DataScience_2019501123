# %%
import pandas as pd
import numpy as np

# %%
ratings = pd.read_csv("E:/DataScience_2019501123/DADV/assignments/data/title.ratings.tsv", delimiter = '\t')

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1702
# 1  tt0000002            6.1       210
# 2  tt0000003            6.5      1458
# 3  tt0000004            6.2       123
# 4  tt0000005            6.2      2260

# %%
basics_movie = pd.read_csv("E:/DataScience_2019501123/DADV/assignments/data/title.basic.tsv", delimiter = '\t')
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
basics_movie.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
rating_above_eight = ratings[ratings['averageRating'] > 8.0]
rating_above_eight
# Out:
#             tconst  averageRating  numVotes
# 275      tt0000361            8.1        10
# 300      tt0000417            8.2     45085
# 611      tt0000961            8.2        13
# 691      tt0001089            8.3        19
# 748      tt0001233            8.6         5
# ...            ...            ...       ...
# 1151587  tt9916380            9.0       104
# 1151590  tt9916460            9.3        15
# 1151592  tt9916538            8.3         6
# 1151595  tt9916578            8.1        25
# 1151597  tt9916628            8.6         5
#
# [226849 rows x 3 columns]

# %%
sorted_Votes = rating_above_eight.sort_values('numVotes', ascending = False).head(20)
sorted_Votes
# Out:
#            tconst  averageRating  numVotes
# 81977   tt0111161            9.3   2388982
# 247668  tt0468569            9.0   2351602
# 601552  tt1375666            8.8   2110186
# 98364   tt0137523            8.8   1889410
# 81760   tt0110912            8.9   1860045
# 80887   tt0109830            8.8   1848201
# 426793  tt0944947            9.3   1807216
# 96238   tt0133093            8.7   1707941
# 89757   tt0120737            8.8   1691012
# 113314  tt0167260            8.9   1670252
# 45804   tt0068646            9.2   1655447
# 390507  tt0816692            8.6   1554804
# 591139  tt1345836            8.4   1542912
# 113315  tt0167261            8.7   1510541
# 416889  tt0903747            9.4   1507039
# 84529   tt0114369            8.6   1474768
# 696641  tt1853728            8.4   1386779
# 115755  tt0172495            8.5   1364292
# 207599  tt0372784            8.2   1330671
# 75175   tt0102926            8.6   1296498

# %%
merged_output = pd.merge(sorted_Votes, basics_movie, on= 'tconst')
merged_output
# Out:
#        tconst  averageRating  numVotes titleType  \
# 0   tt0111161            9.3   2388982     movie
# 1   tt0468569            9.0   2351602     movie
# 2   tt1375666            8.8   2110186     movie
# 3   tt0137523            8.8   1889410     movie
# 4   tt0110912            8.9   1860045     movie
# 5   tt0109830            8.8   1848201     movie
# 6   tt0944947            9.3   1807216  tvSeries
# 7   tt0133093            8.7   1707941     movie
# 8   tt0120737            8.8   1691012     movie
# 9   tt0167260            8.9   1670252     movie
# 10  tt0068646            9.2   1655447     movie
# 11  tt0816692            8.6   1554804     movie
# 12  tt1345836            8.4   1542912     movie
# 13  tt0167261            8.7   1510541     movie
# 14  tt0903747            9.4   1507039  tvSeries
# 15  tt0114369            8.6   1474768     movie
# 16  tt1853728            8.4   1386779     movie
# 17  tt0172495            8.5   1364292     movie
# 18  tt0372784            8.2   1330671     movie
# 19  tt0102926            8.6   1296498     movie
#
#                                          primaryTitle  \
# 0                            The Shawshank Redemption
# 1                                     The Dark Knight
# 2                                           Inception
# 3                                          Fight Club
# 4                                        Pulp Fiction
# 5                                        Forrest Gump
# 6                                     Game of Thrones
# 7                                          The Matrix
# 8   The Lord of the Rings: The Fellowship of the Ring
# 9       The Lord of the Rings: The Return of the King
# 10                                      The Godfather
# 11                                       Interstellar
# 12                              The Dark Knight Rises
# 13              The Lord of the Rings: The Two Towers
# 14                                       Breaking Bad
# 15                                              Se7en
# 16                                   Django Unchained
# 17                                          Gladiator
# 18                                      Batman Begins
# 19                           The Silence of the Lambs
#
#                                         originalTitle isAdult startYear  \
# 0                            The Shawshank Redemption       0      1994
# 1                                     The Dark Knight       0      2008
# 2                                           Inception       0      2010
# 3                                          Fight Club       0      1999
# 4                                        Pulp Fiction       0      1994
# 5                                        Forrest Gump       0      1994
# 6                                     Game of Thrones       0      2011
# 7                                          The Matrix       0      1999
# 8   The Lord of the Rings: The Fellowship of the Ring       0      2001
# 9       The Lord of the Rings: The Return of the King       0      2003
# 10                                      The Godfather       0      1972
# 11                                       Interstellar       0      2014
# 12                              The Dark Knight Rises       0      2012
# 13              The Lord of the Rings: The Two Towers       0      2002
# 14                                       Breaking Bad       0      2008
# 15                                              Se7en       0      1995
# 16                                   Django Unchained       0      2012
# 17                                          Gladiator       0      2000
# 18                                      Batman Begins       0      2005
# 19                           The Silence of the Lambs       0      1991
#
#    endYear runtimeMinutes                   genres
# 0       \N            142                    Drama
# 1       \N            152       Action,Crime,Drama
# 2       \N            148  Action,Adventure,Sci-Fi
# 3       \N            139                    Drama
# 4       \N            154              Crime,Drama
# 5       \N            142            Drama,Romance
# 6     2019             57   Action,Adventure,Drama
# 7       \N            136            Action,Sci-Fi
# 8       \N            178   Action,Adventure,Drama
# 9       \N            201   Action,Adventure,Drama
# 10      \N            175              Crime,Drama
# 11      \N            169   Adventure,Drama,Sci-Fi
# 12      \N            164         Action,Adventure
# 13      \N            179   Action,Adventure,Drama
# 14    2013             49     Crime,Drama,Thriller
# 15      \N            127      Crime,Drama,Mystery
# 16      \N            165            Drama,Western
# 17      \N            155   Action,Adventure,Drama
# 18      \N            140         Action,Adventure
# 19      \N            118     Crime,Drama,Thriller

# %%
movies_type = merged_output.loc[merged_output['titleType'] == 'movie']

# %%
title = movies_type[['originalTitle','averageRating' ]].head(20)
title
# Out:
#                                         originalTitle  averageRating
# 0                            The Shawshank Redemption            9.3
# 1                                     The Dark Knight            9.0
# 2                                           Inception            8.8
# 3                                          Fight Club            8.8
# 4                                        Pulp Fiction            8.9
# 5                                        Forrest Gump            8.8
# 7                                          The Matrix            8.7
# 8   The Lord of the Rings: The Fellowship of the Ring            8.8
# 9       The Lord of the Rings: The Return of the King            8.9
# 10                                      The Godfather            9.2
# 11                                       Interstellar            8.6
# 12                              The Dark Knight Rises            8.4
# 13              The Lord of the Rings: The Two Towers            8.7
# 15                                              Se7en            8.6
# 16                                   Django Unchained            8.4
# 17                                          Gladiator            8.5
# 18                                      Batman Begins            8.2
# 19                           The Silence of the Lambs            8.6

# %%
title.sort_values('averageRating', ascending = False)
# Out:
#                                         originalTitle  averageRating
# 0                            The Shawshank Redemption            9.3
# 10                                      The Godfather            9.2
# 1                                     The Dark Knight            9.0
# 4                                        Pulp Fiction            8.9
# 9       The Lord of the Rings: The Return of the King            8.9
# 2                                           Inception            8.8
# 3                                          Fight Club            8.8
# 5                                        Forrest Gump            8.8
# 8   The Lord of the Rings: The Fellowship of the Ring            8.8
# 7                                          The Matrix            8.7
# 13              The Lord of the Rings: The Two Towers            8.7
# 11                                       Interstellar            8.6
# 15                                              Se7en            8.6
# 19                           The Silence of the Lambs            8.6
# 17                                          Gladiator            8.5
# 12                              The Dark Knight Rises            8.4
# 16                                   Django Unchained            8.4
# 18                                      Batman Begins            8.2

# %%
title.to_csv('E:/DataScience_2019501123/DADV/assignments/popular_movies.csv' )

# %%
type(basics_movie)
# Out:
# pandas.core.frame.DataFrame

# %%
basics_movie.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           object
# startYear         object
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
basics_movie['startYear'] = pd.to_numeric(basics_movie['startYear'], errors='coerce')

# %%
basics_movie.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult            object
# startYear         float64
# endYear            object
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
year = basics_movie[basics_movie.startYear >= 2000]
year
# Out:
#             tconst  titleType               primaryTitle  \
# 11060    tt0011216      movie             Spanish Fiesta
# 11637    tt0011801      movie           Tötet nicht mehr
# 15181    tt0015414      movie     La tierra de los toros
# 16659    tt0016906      movie                 Frivolinas
# 18034    tt0018295      short          El puño de hierro
# ...            ...        ...                        ...
# 7903248  tt9916848  tvEpisode              Episode #3.17
# 7903249  tt9916850  tvEpisode              Episode #3.19
# 7903250  tt9916852  tvEpisode              Episode #3.20
# 7903251  tt9916856      short                   The Wind
# 7903252  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult  startYear endYear runtimeMinutes  \
# 11060            La fête espagnole       0     2019.0      \N             67
# 11637             Tötet nicht mehr       0     2019.0      \N             \N
# 15181       La tierra de los toros       0     2000.0      \N             60
# 16659                   Frivolinas       0     2014.0      \N             80
# 18034            El puño de hierro       0     2004.0      \N             40
# ...                            ...     ...        ...     ...            ...
# 7903248              Episode #3.17       0     2010.0      \N             \N
# 7903249              Episode #3.19       0     2010.0      \N             \N
# 7903250              Episode #3.20       0     2010.0      \N             \N
# 7903251                   The Wind       0     2015.0      \N             27
# 7903252  Horrid Henry Knows It All       0     2014.0      \N             10
#
#                           genres
# 11060                      Drama
# 11637               Action,Crime
# 15181                         \N
# 16659             Comedy,Musical
# 18034         Action,Drama,Short
# ...                          ...
# 7903248      Action,Drama,Family
# 7903249      Action,Drama,Family
# 7903250      Action,Drama,Family
# 7903251                    Short
# 7903252  Animation,Comedy,Family
#
# [5228448 rows x 9 columns]

# %%
year_rating_merged = pd.merge(year, ratings, on= 'tconst')
year_rating_merged
# Out:
#            tconst  titleType                      primaryTitle  \
# 0       tt0011216      movie                    Spanish Fiesta
# 1       tt0015414      movie            La tierra de los toros
# 2       tt0016906      movie                        Frivolinas
# 3       tt0018295      short                 El puño de hierro
# 4       tt0019996      movie                           Hongxia
# ...           ...        ...                               ...
# 778048  tt9916682  tvEpisode  Horrid Henry It's all Your Fault
# 778049  tt9916690  tvEpisode    Horrid Henry Delivers the Milk
# 778050  tt9916720      short                         The Nun 2
# 778051  tt9916766  tvEpisode                    Episode #10.15
# 778052  tt9916778  tvEpisode                            Escape
#
#                            originalTitle isAdult  startYear endYear  \
# 0                      La fête espagnole       0     2019.0      \N
# 1                 La tierra de los toros       0     2000.0      \N
# 2                             Frivolinas       0     2014.0      \N
# 3                      El puño de hierro       0     2004.0      \N
# 4                                Hongxia       0     2011.0      \N
# ...                                  ...     ...        ...     ...
# 778048  Horrid Henry It's all Your Fault       0     2012.0      \N
# 778049    Horrid Henry Delivers the Milk       0     2012.0      \N
# 778050                         The Nun 2       0     2019.0      \N
# 778051                    Episode #10.15       0     2019.0      \N
# 778052                            Escape       0     2019.0      \N
#
#        runtimeMinutes                   genres  averageRating  numVotes
# 0                  67                    Drama            6.3        23
# 1                  60                       \N            5.4        11
# 2                  80           Comedy,Musical            5.6        15
# 3                  40       Action,Drama,Short            6.6        31
# 4                  94                   Action            6.3        52
# ...               ...                      ...            ...       ...
# 778048             10  Animation,Comedy,Family            5.6         5
# 778049             10  Animation,Comedy,Family            6.6         5
# 778050             10    Comedy,Horror,Mystery            6.4        80
# 778051             43        Family,Reality-TV            6.9        16
# 778052             \N    Drama,Mystery,Romance            7.5        27
#
# [778053 rows x 11 columns]

# %%
num_votes = year_rating_merged[year_rating_merged.numVotes > 40000]
num_votes
# Out:
#            tconst     titleType                 primaryTitle  \
# 5       tt0035423         movie               Kate & Leopold
# 59      tt0118694         movie         In the Mood for Love
# 92      tt0120630         movie                  Chicken Run
# 93      tt0120667         movie               Fantastic Four
# 95      tt0120679         movie                        Frida
# ...           ...           ...                          ...
# 774458  tt9784798         movie  Judas and the Black Messiah
# 775241  tt9815454  tvMiniSeries                   Unorthodox
# 776604  tt9866072         movie                     Holidate
# 777306  tt9893250         movie                 I Care a Lot
# 777703  tt9906260     tvEpisode                         Hero
#
#                       originalTitle isAdult  startYear endYear runtimeMinutes  \
# 5                    Kate & Leopold       0     2001.0      \N            118
# 59                 Fa yeung nin wah       0     2000.0      \N             98
# 92                      Chicken Run       0     2000.0      \N             84
# 93                   Fantastic Four       0     2005.0      \N            106
# 95                            Frida       0     2002.0      \N            123
# ...                             ...     ...        ...     ...            ...
# 774458  Judas and the Black Messiah       0     2021.0      \N            126
# 775241                   Unorthodox       0     2020.0    2020            213
# 776604                     Holidate       0     2020.0      \N            104
# 777306                 I Care a Lot       0     2020.0      \N            118
# 777703                         Hero       0     2019.0      \N             24
#
#                             genres  averageRating  numVotes
# 5           Comedy,Fantasy,Romance            6.4     79778
# 59                   Drama,Romance            8.1    129619
# 92      Adventure,Animation,Comedy            7.0    179268
# 93        Action,Adventure,Fantasy            5.7    314357
# 95         Biography,Drama,Romance            7.4     82563
# ...                            ...            ...       ...
# 774458     Biography,Drama,History            7.5     45866
# 775241                       Drama            8.0     61890
# 776604              Comedy,Romance            6.1     48712
# 777306       Comedy,Crime,Thriller            6.3     95099
# 777703  Action,Adventure,Animation            9.9     60115
#
# [3294 rows x 11 columns]

# %%
sorted_rates = num_votes.sort_values('averageRating', ascending = False)
sorted_rates
# Out:
#             tconst  titleType                    primaryTitle  \
# 410908   tt2301451  tvEpisode                      Ozymandias
# 777703   tt9906260  tvEpisode                            Hero
# 533890   tt4283094  tvEpisode             The Winds of Winter
# 756750   tt9166696  tvEpisode                 Vichnaya Pamyat
# 396920   tt2178784  tvEpisode          The Rains of Castamere
# ...            ...        ...                             ...
# 174084  tt10888594      movie                           Radhe
# 224121   tt1213644      movie                  Disaster Movie
# 335805   tt1702443      movie  Justin Bieber: Never Say Never
# 624270   tt5988370      movie                            Reis
# 710251   tt7886848      movie                         Sadak 2
#
#                          originalTitle isAdult  startYear endYear  \
# 410908                      Ozymandias       0     2013.0      \N
# 777703                            Hero       0     2019.0      \N
# 533890             The Winds of Winter       0     2016.0      \N
# 756750                 Vichnaya Pamyat       0     2019.0      \N
# 396920          The Rains of Castamere       0     2013.0      \N
# ...                                ...     ...        ...     ...
# 174084                           Radhe       0     2021.0      \N
# 224121                  Disaster Movie       0     2008.0      \N
# 335805  Justin Bieber: Never Say Never       0     2011.0      \N
# 624270                            Reis       0     2017.0      \N
# 710251                         Sadak 2       0     2020.0      \N
#
#        runtimeMinutes                      genres  averageRating  numVotes
# 410908             48        Crime,Drama,Thriller           10.0    136598
# 777703             24  Action,Adventure,Animation            9.9     60115
# 533890             68      Action,Adventure,Drama            9.9    135520
# 756750             72      Drama,History,Thriller            9.9     54615
# 396920             51      Action,Adventure,Drama            9.9     93347
# ...               ...                         ...            ...       ...
# 174084            135       Action,Crime,Thriller            2.1     40675
# 224121             87               Comedy,Sci-Fi            1.9     87820
# 335805            105           Documentary,Music            1.6     75116
# 624270            108             Biography,Drama            1.4     72612
# 710251            133                Action,Drama            1.1     66069
#
# [3294 rows x 11 columns]

# %%
only_movies = sorted_rates.loc[sorted_rates['titleType'] == 'movie'].head(20)
only_movies
# Out:
#             tconst titleType  \
# 436312   tt2592910     movie
# 144836  tt10189514     movie
# 54918    tt0468569     movie
# 472      tt0167260     movie
# 614610   tt5813916     movie
# 276441   tt1375666     movie
# 99       tt0120737     movie
# 473      tt0167261     movie
# 662173   tt6751668     movie
# 105576   tt0816692     movie
# 3721     tt0245429     movie
# 16566    tt0317248     movie
# 59388    tt0482571     movie
# 4613     tt0253474     movie
# 733305   tt8503618     movie
# 532      tt0172495     movie
# 37160    tt0407887     movie
# 289933   tt1424432     movie
# 331966   tt1675434     movie
# 435788   tt2582802     movie
#
#                                              primaryTitle  \
# 436312                             CM101MMXI Fundamentals
# 144836                                    Soorarai Pottru
# 54918                                     The Dark Knight
# 472         The Lord of the Rings: The Return of the King
# 614610                                    The Mountain II
# 276441                                          Inception
# 99      The Lord of the Rings: The Fellowship of the Ring
# 473                 The Lord of the Rings: The Two Towers
# 662173                                           Parasite
# 105576                                       Interstellar
# 3721                                        Spirited Away
# 16566                                         City of God
# 59388                                        The Prestige
# 4613                                          The Pianist
# 733305                                           Hamilton
# 532                                             Gladiator
# 37160                                        The Departed
# 289933                                              Senna
# 331966                                   The Intouchables
# 435788                                           Whiplash
#
#                                             originalTitle isAdult  startYear  \
# 436312                             CM101MMXI Fundamentals       0     2013.0
# 144836                                    Soorarai Pottru       0     2020.0
# 54918                                     The Dark Knight       0     2008.0
# 472         The Lord of the Rings: The Return of the King       0     2003.0
# 614610                                             Dag II       0     2016.0
# 276441                                          Inception       0     2010.0
# 99      The Lord of the Rings: The Fellowship of the Ring       0     2001.0
# 473                 The Lord of the Rings: The Two Towers       0     2002.0
# 662173                                       Gisaengchung       0     2019.0
# 105576                                       Interstellar       0     2014.0
# 3721                        Sen to Chihiro no kamikakushi       0     2001.0
# 16566                                      Cidade de Deus       0     2002.0
# 59388                                        The Prestige       0     2006.0
# 4613                                          The Pianist       0     2002.0
# 733305                                           Hamilton       0     2020.0
# 532                                             Gladiator       0     2000.0
# 37160                                        The Departed       0     2006.0
# 289933                                              Senna       0     2010.0
# 331966                                       Intouchables       0     2011.0
# 435788                                           Whiplash       0     2014.0
#
#        endYear runtimeMinutes                       genres  averageRating  \
# 436312      \N            139           Comedy,Documentary            9.2
# 144836      \N            153                        Drama            9.1
# 54918       \N            152           Action,Crime,Drama            9.0
# 472         \N            201       Action,Adventure,Drama            8.9
# 614610      \N            135             Action,Drama,War            8.8
# 276441      \N            148      Action,Adventure,Sci-Fi            8.8
# 99          \N            178       Action,Adventure,Drama            8.8
# 473         \N            179       Action,Adventure,Drama            8.7
# 662173      \N            132        Comedy,Drama,Thriller            8.6
# 105576      \N            169       Adventure,Drama,Sci-Fi            8.6
# 3721        \N            125   Adventure,Animation,Family            8.6
# 16566       \N            130                  Crime,Drama            8.6
# 59388       \N            130         Drama,Mystery,Sci-Fi            8.5
# 4613        \N            150        Biography,Drama,Music            8.5
# 733305      \N            160      Biography,Drama,History            8.5
# 532         \N            155       Action,Adventure,Drama            8.5
# 37160       \N            151         Crime,Drama,Thriller            8.5
# 289933      \N            106  Biography,Documentary,Sport            8.5
# 331966      \N            112       Biography,Comedy,Drama            8.5
# 435788      \N            106                  Drama,Music            8.5
#
#         numVotes
# 436312     44221
# 144836     62010
# 54918    2351602
# 472      1670252
# 614610    105922
# 276441   2110186
# 99       1691012
# 473      1510541
# 662173    604246
# 105576   1554804
# 3721      669324
# 16566     708623
# 59388    1213717
# 4613      747394
# 733305     63986
# 532      1364292
# 37160    1211342
# 289933     65185
# 331966    777218
# 435788    737144

# %%
best_movies= only_movies[['originalTitle','numVotes', 'startYear','averageRating' ]].head(20)
best_movies
# Out:
#                                             originalTitle  numVotes  \
# 436312                             CM101MMXI Fundamentals     44221
# 144836                                    Soorarai Pottru     62010
# 54918                                     The Dark Knight   2351602
# 472         The Lord of the Rings: The Return of the King   1670252
# 614610                                             Dag II    105922
# 276441                                          Inception   2110186
# 99      The Lord of the Rings: The Fellowship of the Ring   1691012
# 473                 The Lord of the Rings: The Two Towers   1510541
# 662173                                       Gisaengchung    604246
# 105576                                       Interstellar   1554804
# 3721                        Sen to Chihiro no kamikakushi    669324
# 16566                                      Cidade de Deus    708623
# 59388                                        The Prestige   1213717
# 4613                                          The Pianist    747394
# 733305                                           Hamilton     63986
# 532                                             Gladiator   1364292
# 37160                                        The Departed   1211342
# 289933                                              Senna     65185
# 331966                                       Intouchables    777218
# 435788                                           Whiplash    737144
#
#         startYear  averageRating
# 436312     2013.0            9.2
# 144836     2020.0            9.1
# 54918      2008.0            9.0
# 472        2003.0            8.9
# 614610     2016.0            8.8
# 276441     2010.0            8.8
# 99         2001.0            8.8
# 473        2002.0            8.7
# 662173     2019.0            8.6
# 105576     2014.0            8.6
# 3721       2001.0            8.6
# 16566      2002.0            8.6
# 59388      2006.0            8.5
# 4613       2002.0            8.5
# 733305     2020.0            8.5
# 532        2000.0            8.5
# 37160      2006.0            8.5
# 289933     2010.0            8.5
# 331966     2011.0            8.5
# 435788     2014.0            8.5

# %%
best_movies.sort_values('numVotes', ascending=False)
# Out:
#                                             originalTitle  numVotes  \
# 54918                                     The Dark Knight   2351602
# 276441                                          Inception   2110186
# 99      The Lord of the Rings: The Fellowship of the Ring   1691012
# 472         The Lord of the Rings: The Return of the King   1670252
# 105576                                       Interstellar   1554804
# 473                 The Lord of the Rings: The Two Towers   1510541
# 532                                             Gladiator   1364292
# 59388                                        The Prestige   1213717
# 37160                                        The Departed   1211342
# 331966                                       Intouchables    777218
# 4613                                          The Pianist    747394
# 435788                                           Whiplash    737144
# 16566                                      Cidade de Deus    708623
# 3721                        Sen to Chihiro no kamikakushi    669324
# 662173                                       Gisaengchung    604246
# 614610                                             Dag II    105922
# 289933                                              Senna     65185
# 733305                                           Hamilton     63986
# 144836                                    Soorarai Pottru     62010
# 436312                             CM101MMXI Fundamentals     44221
#
#         startYear  averageRating
# 54918      2008.0            9.0
# 276441     2010.0            8.8
# 99         2001.0            8.8
# 472        2003.0            8.9
# 105576     2014.0            8.6
# 473        2002.0            8.7
# 532        2000.0            8.5
# 59388      2006.0            8.5
# 37160      2006.0            8.5
# 331966     2011.0            8.5
# 4613       2002.0            8.5
# 435788     2014.0            8.5
# 16566      2002.0            8.6
# 3721       2001.0            8.6
# 662173     2019.0            8.6
# 614610     2016.0            8.8
# 289933     2010.0            8.5
# 733305     2020.0            8.5
# 144836     2020.0            9.1
# 436312     2013.0            9.2

# %%
best_movies.to_csv('E:/DataScience_2019501123/DADV/assignments/movie_highvotes.csv')
